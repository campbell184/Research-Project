# %% [markdown]
# # **ENSEMBLE-META BASED TREES (VOTING CLASSIFIER): STUDENT DATASET**

# %%
# Installations
# !pip install imbalanced-learn

# Imports
import time
import random
import pickle
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from google.colab import drive
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
from sklearn.preprocessing import StandardScaler

# Reproducible results
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.21.6)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from imbalanced-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24->imbalanced-learn) (3.1.0)

# %%
# 1. Mount google drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **A. FIRST YEAR DATASET**

# %% [markdown]
# #### **1. DISPLAY THE DATASET**

# %%
# 1. load and display the train dataset
df = pd.read_csv('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/first_year_train.csv')
df.head()
# Out:
#    Unnamed: 0  YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0           0     0.633229  0.813618         0.291103               1.400196
# 1           1    -1.065648 -0.130947        -0.635273              -1.162318
# 2           2     1.312780 -1.075512         0.291103               1.187297
# 3           3    -0.386097 -0.045078        -0.542636              -0.386634
# 4           4     1.312780 -1.075512         0.291103              -0.495935
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.900613            -0.660940       0.618172
# 1                -0.739018             2.484212       0.641247
# 2                -0.900613            -0.660940      -1.099003
# 3                 0.530659            -0.660940      -1.101578
# 4                 1.604113             0.209593       0.256748
#
#    RaceDescription  AgeatFirstYear  LifeOrientation  EnglishFirstLang  \
# 0        -0.659496       -0.342259         0.543607     -4.611209e-03
# 1         1.802742        0.958744         0.668683      1.253807e+00
# 2        -0.659496       -1.318012        -2.082976      2.554742e-15
# 3        -0.659496        0.308242        -0.081769      2.554742e-15
# 4        -0.659496       -1.318012         0.793758     -1.843852e-01
#
#    EnglishFirstAdditional     NBTAL         NBTMA         NBTQL  \
# 0                0.000000 -0.310131  1.407877e+00 -6.116022e-01
# 1                0.000000  0.330381 -2.561529e-01  3.636643e-01
# 2               -0.444814 -1.225148  2.854859e+00 -1.436828e+00
# 3               -1.459788  0.421883 -1.114547e-01 -1.061725e+00
# 4                0.000000  0.000000 -5.140714e-16 -5.330527e-16
#
#    ProgressoutcomeYOS1
# 0                    4
# 1                    4
# 2                    0
# 3                    2
# 4                    4

# %%
# 2. remove the 'Unnamed: 0' column 
df = df.drop(columns=['Unnamed: 0'])

# %%
# 3. load the pickle file.
with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/first_year_map.pkl', 'rb') as fid:
  MAP = pickle.load(fid)

# %%
# 4. display the train dataset
df.head()
# Out:
#    YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0     0.633229  0.813618         0.291103               1.400196
# 1    -1.065648 -0.130947        -0.635273              -1.162318
# 2     1.312780 -1.075512         0.291103               1.187297
# 3    -0.386097 -0.045078        -0.542636              -0.386634
# 4     1.312780 -1.075512         0.291103              -0.495935
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.900613            -0.660940       0.618172
# 1                -0.739018             2.484212       0.641247
# 2                -0.900613            -0.660940      -1.099003
# 3                 0.530659            -0.660940      -1.101578
# 4                 1.604113             0.209593       0.256748
#
#    RaceDescription  AgeatFirstYear  LifeOrientation  EnglishFirstLang  \
# 0        -0.659496       -0.342259         0.543607     -4.611209e-03
# 1         1.802742        0.958744         0.668683      1.253807e+00
# 2        -0.659496       -1.318012        -2.082976      2.554742e-15
# 3        -0.659496        0.308242        -0.081769      2.554742e-15
# 4        -0.659496       -1.318012         0.793758     -1.843852e-01
#
#    EnglishFirstAdditional     NBTAL         NBTMA         NBTQL  \
# 0                0.000000 -0.310131  1.407877e+00 -6.116022e-01
# 1                0.000000  0.330381 -2.561529e-01  3.636643e-01
# 2               -0.444814 -1.225148  2.854859e+00 -1.436828e+00
# 3               -1.459788  0.421883 -1.114547e-01 -1.061725e+00
# 4                0.000000  0.000000 -5.140714e-16 -5.330527e-16
#
#    ProgressoutcomeYOS1
# 0                    4
# 1                    4
# 2                    0
# 3                    2
# 4                    4

# %%
# 5. display the map keys
print('MAP Keys:')
print(np.array(list(MAP.keys())))
# Out:
# MAP Keys:
# ['PlanCode' 'PlanDescription' 'RaceDescription' 'Language' 'Gender'
#  'Homeprovince' 'Homecountry' 'isRuralorUrban' 'YearStarted'
#  'ProgressoutcomeYOS1' 'FIRST_YEAR_IMPUTATION'
#  'first_year_feature_selector' 'first_year_scaler']

# %%
# 6. print the number of columns
print('No. of columns:', len(df.columns))
print('No. of rows:', len(df))
print('No. of nulls:', df.isna().sum().sum())
# Out:
# No. of columns: 16
# No. of rows: 5450
# No. of nulls: 0

# %% [markdown]
# #### **2. TRAIN VOTING CLASSIER MODEL**

# %%
# 1. Generate the X and y sets.
f_y = df['ProgressoutcomeYOS1']
f_X = df.drop(columns=['ProgressoutcomeYOS1'])

# %%
# 2. load the models.
with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/rf_tree_first_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  random_forest_params = model.get_params()
  random_forest_params = random_forest_params['steps'][1][1].get_params()

with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/decision_tree_first_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  decision_tree_params = model.get_params()
  decision_tree_params = decision_tree_params['steps'][1][1].get_params()

with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/mlp_first_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  mlp_params = model.get_params()
  mlp_params = mlp_params['steps'][1][1].get_params()

# %%
# 3. Initialize the model and define pipeline to perform oversampling.
clf1 = RandomForestClassifier().set_params(**random_forest_params)
clf2 = DecisionTreeClassifier().set_params(**decision_tree_params)
clf3 = MLPClassifier().set_params(**mlp_params)
voting_clf = VotingClassifier(estimators=[('random_forests', clf1), 
                                          ('decision_tree', clf2), 
                                          ('neural_network', clf3)])
steps = [('over', SMOTE(random_state=SEED)), 
         ('model', voting_clf)]
pipeline = Pipeline(steps=steps)

# %%
# 4. Define evaluation
cross_val = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=SEED)

# %%
# 5. define search space
search_space = {'model__voting': ['hard', 'soft'],
                'model__verbose': [True]}

# %%
# 6. Define the GridSearch
search = GridSearchCV(pipeline, search_space, scoring='accuracy', n_jobs=-1, cv=cross_val, return_train_score=True)

# %%
# 7. Execute the search
result = search.fit(f_X, f_y)
# Out:
# [Voting] ........... (1 of 3) Processing random_forests, total=  17.9s
# [Voting] ............ (2 of 3) Processing decision_tree, total=   0.2s
# Iteration 1, loss = 1.80713562
# Iteration 2, loss = 1.49985903
# Iteration 502, loss = 0.47397443
# Iteration 503, loss = 0.47498256
# Iteration 504, loss = 0.47494066
# Iteration 505, loss = 0.47367521
# Iteration 506, loss = 0.47399082
# Iteration 507, loss = 0.47486735
# Iteration 508, loss = 0.47408443
# Iteration 509, loss = 0.47509399
# Iteration 510, loss = 0.47468793
# Iteration 511, loss = 0.47457325
# Iteration 512, loss = 0.47491860
# Iteration 513, loss = 0.47470781
# Iteration 514, loss = 0.47299767
# Iteration 515, loss = 0.47460904
# Iteration 516, loss = 0.47382440
# Iteration 517, loss = 0.47357050
# Iteration 518, loss = 0.47306084
# Iteration 519, loss = 0.47337153
# Iteration 520, loss = 0.47331967
# Iteration 521, loss = 0.47328589
# Iteration 522, loss = 0.47323997
# Iteration 523, loss = 0.47276620
# Iteration 524, loss = 0.47301442
# Iteration 525, loss = 0.47348386
# Iteration 526, loss = 0.47362810
# Iteration 527, loss = 0.47343579
# Iteration 528, loss = 0.47308929
# Iteration 529, loss = 0.47335683
# Iteration 530, loss = 0.47299590
# Iteration 531, loss = 0.47235742
# Iteration 532, loss = 0.47342824
# Iteration 533, loss = 0.47360309
# Iteration 534, loss = 0.47260856
# Iteration 535, loss = 0.47341021
# Iteration 536, loss = 0.47318043
# Iteration 537, loss = 0.47279368
# Iteration 538, loss = 0.47243292
# Iteration 539, loss = 0.47287240
# Iteration 540, loss = 0.47144190
# Iteration 541, loss = 0.47195769
# Iteration 542, loss = 0.47223927
# Iteration 543, loss = 0.47181672
# Iteration 544, loss = 0.47228858
# Iteration 545, loss = 0.47153591
# Iteration 546, loss = 0.47142385
# Iteration 547, loss = 0.47265072
# Iteration 548, loss = 0.47207951
# Iteration 549, loss = 0.47205936
# Iteration 550, loss = 0.47179689
# Iteration 551, loss = 0.47197570
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [Voting] ........... (3 of 3) Processing neural_network, total=  39.5s

# %%
# 8. Display the results
print('Best Accuracy Score:', result.best_score_)
print('Best Hyperparameters:', result.best_params_)
print('Mean train scores:', result.cv_results_['mean_train_score'])
print('Mean test scores:', result.cv_results_['mean_test_score'])
# Out:
# Best Accuracy Score: 0.6823853211009174
# Best Hyperparameters: {'model__verbose': True, 'model__voting': 'soft'}
# Mean train scores: [0.84350663 0.86501529]
# Mean test scores: [0.68201835 0.68238532]

# %% [markdown]
# #### **3. EVALUATE THE MODEL ON TEST DATASET.**

# %% [markdown]
# ###### **3.1. LOAD THE TEST DATASET**

# %%
# 1. load the test dataset.
df_test = pd.read_csv('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/first_year_test.csv')
df_test.head()
# Out:
#    Unnamed: 0  YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0        7477            3        19                9               0.058824
# 1        9134            8        30               19               0.250000
# 2       13723            6        20               10               0.015152
# 3        6760            8        30               19               0.863636
# 4        4873            8        30               19               0.791667
#
#    ProbOfPhysicsStreamline  ProbofEarthStreamline  ProbofBioStreamline  \
# 0                 0.117647                    0.0             0.764706
# 1                 0.166667                    0.0             0.416667
# 2                 0.015152                    0.0             0.969697
# 3                 0.000000                    0.0             0.000000
# 4                 0.208333                    0.0             0.000000
#
#    AggregateYOS1  RaceDescription  ...  MathematicsMatricLit  \
# 0      45.400000                0  ...                   NaN
# 1      53.000000                0  ...                   NaN
# 2      65.888889                0  ...                   NaN
# 3      50.285714                0  ...                   NaN
# 4      94.500000                4  ...                   NaN
#
#    MathematicsMatricMajor  EnglishFirstLang  EnglishFirstAdditional  \
# 0                    35.0              64.0                     NaN
# 1                    33.0              66.0                     NaN
# 2                    42.0              75.0                     NaN
# 3                    66.0               NaN                    73.0
# 4                    95.0              85.0                     NaN
#
#    Computers  AdditionalMathematics  NBTAL  NBTMA  NBTQL  ProgressoutcomeYOS1
# 0        NaN                    NaN   56.0   35.0   51.0                    4
# 1        NaN                    NaN   73.0   33.0   39.0                    4
# 2        NaN                    NaN   58.0   42.0   59.0                    4
# 3        NaN                    NaN   61.0   66.0   53.0                    4
# 4        NaN                   94.0    NaN    NaN    NaN                    4
#
# [5 rows x 27 columns]

# %%
# 2. remove the 'Unnamed: 0' column 
df_test = df_test.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ###### **3.2. PREPROCESS THE TEST DATASET**

# %%
# 1. Impute the null values using the means from Train dataset
df_test = df_test.fillna(MAP['FIRST_YEAR_IMPUTATION'])

# %%
# 2. Initialize the feature selector
first_year_fs = MAP['first_year_feature_selector']

# %%
# 3. Get the X from the test dataset and select k best features using the train feature selector
f_X_test = df_test.drop(columns=['ProgressoutcomeYOS1'])
f_y_test = df_test['ProgressoutcomeYOS1']
f_X_test = first_year_fs.transform(f_X_test)
f_X_test = pd.DataFrame(f_X_test)
f_X_test.columns = first_year_fs.get_feature_names_out()

# %%
# 4. Initialize the Standardizer
first_year_scaler = MAP['first_year_scaler']

# %%
# 5. Standardize the X_test using the standardizer used for the train dataset.
f_X_test = first_year_scaler.transform(f_X_test)
f_X_test = pd.DataFrame(f_X_test)
f_X_test.columns = first_year_fs.get_feature_names_out()
f_X_test.head()
# Out:
#    YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0    -0.725872 -0.130947        -0.635273              -1.081016
# 1     0.973004  0.813618         0.291103              -0.495935
# 2     0.293454 -0.045078        -0.542636              -1.214671
# 3     0.973004  0.813618         0.291103               1.382052
# 4     0.973004  0.813618         0.291103               1.161794
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.311266             2.001867      -0.697299
# 1                -0.065705             0.789948      -0.110193
# 2                -0.824713             2.715673       0.885484
# 3                -0.900613            -0.660940      -0.319874
# 4                 0.143022            -0.660940       3.095714
#
#    RaceDescription  AgeatFirstYear  LifeOrientation  EnglishFirstLang  \
# 0        -0.659496        0.633493        -0.832222     -1.802351e+00
# 1        -0.659496       -1.318012         0.418532     -1.442803e+00
# 2        -0.659496       -0.017009        -0.081769      1.751628e-01
# 3        -0.659496       -0.992761        -0.456996      2.554742e-15
# 4         1.802742       -0.992761         1.294060      1.972902e+00
#
#    EnglishFirstAdditional     NBTAL         NBTMA         NBTQL
# 0                0.000000 -0.401633 -1.196691e+00 -3.115202e-01
# 1                0.000000  1.153896 -1.341390e+00 -1.211766e+00
# 2                0.000000 -0.218629 -6.902476e-01  2.886438e-01
# 3               -0.038825  0.055876  1.046131e+00 -1.614792e-01
# 4                0.000000  0.000000 -5.140714e-16 -5.330527e-16

# %%
# 6. print the number of columns
print('No. of columns in X:', len(f_X_test.columns))
print('No. of rows in X:', len(f_X_test))
print('No. of nulls in X:', f_X_test.isna().sum().sum(), '\n')

print('No. of rows in Y:', len(f_y_test))
print('No. of nulls in Y:', f_y_test.isna().sum().sum())
# Out:
# No. of columns in X: 15
# No. of rows in X: 1363
# No. of nulls in X: 0
#
# No. of rows in Y: 1363
# No. of nulls in Y: 0

# %% [markdown]
# ###### **3.3. EVALUATE THE MODEL**

# %%
def plot_confusion_matrix(true_labels, pred_labels, labels):
  '''
  Plots the confusion matrix
  '''
  # compute the matrix
  matrix = confusion_matrix(true_labels, pred_labels, labels=np.arange(len(labels)))
  # create a figure of the matrix
  fig = ConfusionMatrixDisplay(confusion_matrix=matrix, display_labels=labels)
  # rotate the x_labels
  fig.plot(xticks_rotation='vertical')
  # plot the matrix
  plt.show()

# %%
# 1. compute the Accuracy, Recall, Precision and F1-Score for test dataset.
f_y_test_pred = result.best_estimator_.predict(f_X_test)
print('============= Test Scores =============')
print('Accuracy Score:', accuracy_score(f_y_test, f_y_test_pred))
print('Recall Score:', recall_score(f_y_test, f_y_test_pred, average='micro'))
print('Precision Score:', precision_score(f_y_test, f_y_test_pred, average='micro'))
print('F1-Score:', f1_score(f_y_test, f_y_test_pred, average='micro'))
# Out:
# ============= Test Scores =============
# Accuracy Score: 0.6823184152604549
# Recall Score: 0.6823184152604549
# Precision Score: 0.6823184152604549
# F1-Score: 0.6823184152604549

# %%
# 2. plot confusion matrix
labels = np.array(sorted(MAP['ProgressoutcomeYOS1'].items(), key=lambda item: item[1]))[:,0]
plot_confusion_matrix(f_y_test, f_y_test_pred, labels)

# %%
# 3. save the model.
with open('/content/gdrive/MyDrive/COMS HONS RESEARCH PROJECT/ensemble_trees_first_year.pkl', 'wb') as fid:
  pickle.dump(result.best_estimator_, fid)

# %% [markdown]
# ## **B. SECOND YEAR DATASET**

# %% [markdown]
# #### **1. DISPLAY THE DATASET**

# %%
# 1. load and display the train dataset
df = pd.read_csv('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/second_year_train.csv')
df.head()
# Out:
#    Unnamed: 0  YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0           0     1.412382 -1.193108        -1.428669               1.193993
# 1           1     1.022954 -1.193108        -1.428669               1.276913
# 2           2     0.244097  0.106569         0.153156               0.952548
# 3           3    -1.703046 -1.665717         3.203819              -0.936027
# 4           4     1.022954  1.169941         1.057056               0.317920
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.667475            -0.686405       1.249947
# 1                -0.667475            -0.686405       2.709529
# 2                -0.667475            -0.686405       0.956004
# 3                 2.824622            -0.686405      -0.298957
# 4                 0.996057            -0.686405      -0.897613
#
#    ProgressoutcomeYOS1  Firstyearoutcome  ...  Language  Homeprovince  \
# 0             0.005711          0.506922  ... -1.005582      0.326652
# 1             0.005711          0.506922  ... -1.005582     -0.439724
# 2             0.005711          0.506922  ... -1.005582     -0.439724
# 3             0.005711          0.506922  ... -1.005582     -0.439724
# 4             1.274687         -1.972691  ...  1.472077      0.326652
#
#    AgeatFirstYear  AgeatSecondYear  EnglishFirstLang  EnglishFirstAdditional  \
# 0       -1.418129        -1.418129      2.704824e+00            3.106592e-15
# 1       -1.044375        -1.044375      2.539227e+00            3.106592e-15
# 2       -0.296865        -0.296865      8.832487e-01            3.106592e-15
# 3        1.571908         1.571908      1.545640e+00            3.106592e-15
# 4       -1.044375        -1.044375     -2.353286e-15            1.102392e+00
#
#       Computers     NBTAL         NBTQL  ProgressoutcomeYOS2
# 0  2.929565e+00  0.829917  2.167776e+00                    4
# 1 -3.129260e-15  0.000000  1.055208e-15                    4
# 2 -3.734665e-01  0.548778 -2.825948e-01                    4
# 3 -3.129260e-15  1.298482  2.613298e+00                    4
# 4 -3.129260e-15  0.000000  1.055208e-15                    5
#
# [5 rows x 22 columns]

# %%
# 2. remove the 'Unnamed: 0' column 
df = df.drop(columns=['Unnamed: 0'])

# %%
# 3. load the pickle file.
with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/second_year_map.pkl', 'rb') as fid:
  MAP = pickle.load(fid)

# %%
# 4. display the train dataset
df.head()
# Out:
#    YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0     1.412382 -1.193108        -1.428669               1.193993
# 1     1.022954 -1.193108        -1.428669               1.276913
# 2     0.244097  0.106569         0.153156               0.952548
# 3    -1.703046 -1.665717         3.203819              -0.936027
# 4     1.022954  1.169941         1.057056               0.317920
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.667475            -0.686405       1.249947
# 1                -0.667475            -0.686405       2.709529
# 2                -0.667475            -0.686405       0.956004
# 3                 2.824622            -0.686405      -0.298957
# 4                 0.996057            -0.686405      -0.897613
#
#    ProgressoutcomeYOS1  Firstyearoutcome  AggregateYOS2  ...  Language  \
# 0             0.005711          0.506922       0.916101  ... -1.005582
# 1             0.005711          0.506922       1.268135  ... -1.005582
# 2             0.005711          0.506922       0.215177  ... -1.005582
# 3             0.005711          0.506922       1.801773  ... -1.005582
# 4             1.274687         -1.972691      -1.071946  ...  1.472077
#
#    Homeprovince  AgeatFirstYear  AgeatSecondYear  EnglishFirstLang  \
# 0      0.326652       -1.418129        -1.418129      2.704824e+00
# 1     -0.439724       -1.044375        -1.044375      2.539227e+00
# 2     -0.439724       -0.296865        -0.296865      8.832487e-01
# 3     -0.439724        1.571908         1.571908      1.545640e+00
# 4      0.326652       -1.044375        -1.044375     -2.353286e-15
#
#    EnglishFirstAdditional     Computers     NBTAL         NBTQL  \
# 0            3.106592e-15  2.929565e+00  0.829917  2.167776e+00
# 1            3.106592e-15 -3.129260e-15  0.000000  1.055208e-15
# 2            3.106592e-15 -3.734665e-01  0.548778 -2.825948e-01
# 3            3.106592e-15 -3.129260e-15  1.298482  2.613298e+00
# 4            1.102392e+00 -3.129260e-15  0.000000  1.055208e-15
#
#    ProgressoutcomeYOS2
# 0                    4
# 1                    4
# 2                    4
# 3                    4
# 4                    5
#
# [5 rows x 21 columns]

# %%
# 5. display the map keys
print('MAP Keys:')
print(np.array(list(MAP.keys())))
# Out:
# MAP Keys:
# ['PlanCode' 'PlanDescription' 'RaceDescription' 'Language' 'Gender'
#  'Homeprovince' 'Homecountry' 'isRuralorUrban' 'YearStarted'
#  'Firstyearoutcome' 'ProgressoutcomeYOS1' 'ProgressoutcomeYOS2'
#  'SECOND_YEAR_IMPUTATION' 'second_year_feature_selector'
#  'second_year_scaler']

# %%
# 6. print the number of columns
print('No. of columns:', len(df.columns))
print('No. of rows:', len(df))
print('No. of nulls:', df.isna().sum().sum())
# Out:
# No. of columns: 21
# No. of rows: 3111
# No. of nulls: 0

# %% [markdown]
# #### **2. TRAIN VOTING CLASSIFIER MODEL**

# %%
# 1. Generate the X and y sets.
s_y = df['ProgressoutcomeYOS2']
s_X = df.drop(columns=['ProgressoutcomeYOS2'])

# %%
# 2. load the models.
with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/rf_tree_second_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  random_forest_params = model.get_params()
  random_forest_params = random_forest_params['steps'][1][1].get_params()

with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/decision_tree_second_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  decision_tree_params = model.get_params()
  decision_tree_params = decision_tree_params['steps'][1][1].get_params()

with open('gdrive/MyDrive/COMS HONS RESEARCH PROJECT/mlp_second_year.pkl', 'rb') as fid:
  model = pickle.load(fid)
  mlp_params = model.get_params()
  mlp_params = mlp_params['steps'][1][1].get_params()

# %%
# 2. Initialize the model and define pipeline to perform oversampling.
clf1 = RandomForestClassifier().set_params(**random_forest_params)
clf2 = DecisionTreeClassifier().set_params(**decision_tree_params)
clf3 = MLPClassifier().set_params(**mlp_params)
voting_clf = VotingClassifier(estimators=[('random_forests', clf1), 
                                          ('decision_tree', clf2), 
                                          ('neural_network', clf3)])
steps = [('over', SMOTE(random_state=SEED)), 
         ('model', voting_clf)]
pipeline = Pipeline(steps=steps)

# %%
# 4. Define evaluation
cross_val = RepeatedStratifiedKFold(n_splits=10, n_repeats=1, random_state=SEED)

# %%
# 5. define search space
search_space = {'model__voting': ['hard', 'soft'],
                'model__verbose': [True]}

# %%
# 6. Define the GridSearch
search = GridSearchCV(pipeline, search_space, scoring='accuracy', n_jobs=-1, cv=cross_val, return_train_score=True)

# %%
# 6. Execute the search
result = search.fit(s_X, s_y)
# Out:
# [Voting] ........... (1 of 3) Processing random_forests, total=   7.0s
# [Voting] ............ (2 of 3) Processing decision_tree, total=   0.2s
# Iteration 1, loss = 1.86828003
# Iteration 2, loss = 1.74851465
# Iteration 3, loss = 1.58345885
# Iteration 4, loss = 1.44519056
# Iteration 5, loss = 1.26109778
# Iteration 6, loss = 1.06336569
# Iteration 7, loss = 0.94292971
# Iteration 8, loss = 0.85816548
# Iteration 9, loss = 0.79714726
# Iteration 10, loss = 0.74807773
# Iteration 11, loss = 0.70781387
# Iteration 12, loss = 0.67444806
# Iteration 13, loss = 0.64493795
# Iteration 14, loss = 0.61852188
earStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0        5897            3        19               15               0.025641
# 1        2456            7        22               19               0.055556
# 2        8379            6         4                0               0.850000
# 3        2688            3         5                1               0.014706
# 4        8334            8        21               18               0.272727
#
#    ProbOfPhysicsStreamline  ProbofEarthStreamline  ProbofBioStreamline  \
# 0                 0.025641               0.000000             0.948718
# 1                 0.111111               0.000000             0.555556
# 2                 0.000000               0.000000             0.000000
# 3                 0.029412               0.955882             0.000000
# 4                 0.727273               0.000000             0.000000
#
#    AggregateYOS1  ProgressoutcomeYOS1  ...  MathematicsMatricLit  \
# 0      65.769231                    3  ...                   NaN
# 1      66.500000                    3  ...                   NaN
# 2      49.000000                    3  ...                   NaN
# 3      61.333333                    3  ...                   NaN
# 4      58.000000                    3  ...                   NaN
#
#    MathematicsMatricMajor  EnglishFirstLang  EnglishFirstAdditional  \
# 0                    70.0              74.0                     NaN
# 1                    33.0              87.0                     NaN
# 2                    43.0               NaN                    73.0
# 3                    37.0               NaN                    71.0
# 4                    37.0               NaN                    66.0
#
#    Computers  AdditionalMathematics  NBTAL  NBTMA  NBTQL  ProgressoutcomeYOS2
# 0        NaN                    NaN    NaN    NaN    NaN                    4
# 1        NaN                   38.0   74.0   33.0   49.0                    4
# 2        NaN                    NaN   58.0   43.0   62.0                    1
# 3        NaN                    NaN   39.0   37.0   46.0                    4
# 4        NaN                    NaN   51.0   37.0   36.0                    4
#
# [5 rows x 31 columns]

# %%
# 2. remove the 'Unnamed: 0' column 
df_test = df_test.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ###### **3.2. PREPROCESS THE TEST DATASET**

# %%
# 1. Impute the null values using the means from Train dataset
df_test = df_test.fillna(MAP['SECOND_YEAR_IMPUTATION'])

# %%
# 2. Initialize the feature selector
second_year_fs = MAP['second_year_feature_selector']

# %%
# 3. Get the X from the test dataset and select k best features using the train feature selector
s_X_test = df_test.drop(columns=['ProgressoutcomeYOS2'])
s_y_test = df_test['ProgressoutcomeYOS2']
s_X_test = second_year_fs.transform(s_X_test)
s_X_test = pd.DataFrame(s_X_test)
s_X_test.columns = second_year_fs.get_feature_names_out()

# %%
# 4. Initialize the Standardizer
second_year_scaler = MAP['second_year_scaler']

# %%
# 5. Standardize the X_test using the standardizer used for the train dataset.
s_X_test = second_year_scaler.transform(s_X_test)
s_X_test = pd.DataFrame(s_X_test)
s_X_test.columns = second_year_fs.get_feature_names_out()
s_X_test.head()
# Out:
#    YearStarted  PlanCode  PlanDescription  ProbOfMatheStreamline  \
# 0    -0.534760  0.579179         0.266144              -0.977886
# 1     1.022954  0.933636         0.718094              -0.899750
# 2     0.633525 -1.193108        -1.428669               1.175336
# 3    -0.534760 -1.074955        -1.315682              -1.006449
# 4     1.412382  0.815483         0.605106              -0.332498
#
#    ProbOfPhysicsStreamline  ProbofBioStreamline  AggregateYOS1  \
# 0                -0.527324             2.109834       0.647636
# 1                -0.060154             0.951032       0.725410
# 2                -0.667475            -0.686405      -1.137076
# 3                -0.506713            -0.686405       0.175533
# 4                 3.307718            -0.686405      -0.179226
#
#    ProgressoutcomeYOS1  Firstyearoutcome  AggregateYOS2  RaceDescription  \
# 0             0.005711          0.506922       0.413196        -0.729872
# 1             0.005711          0.506922       1.161267         1.631679
# 2             0.005711          0.506922      -2.040039        -0.729872
# 3             0.005711          0.506922       0.207843        -0.729872
# 4             0.005711          0.506922       0.090498        -0.729872
#
#    Language  Homeprovince  AgeatFirstYear  AgeatSecondYear  EnglishFirstLang  \
# 0  1.472077     -0.439724        0.450644         0.450644     -1.103381e-01
# 1 -1.005582     -0.439724       -1.044375        -1.044375      2.042433e+00
# 2  1.196781      1.093029       -0.670620        -0.670620     -2.353286e-15
# 3  1.472077      0.326652        0.450644         0.450644     -2.353286e-15
# 4  0.003835     -0.439724       -1.044375        -1.044375     -2.353286e-15
#
#    EnglishFirstAdditional     Computers     NBTAL         NBTQL
# 0            3.106592e-15 -3.129260e-15  0.000000  1.055208e-15
# 1            3.106592e-15 -3.129260e-15  1.111056 -5.796095e-01
# 2            9.356719e-03 -3.129260e-15 -0.388352  3.856882e-01
# 3           -4.278572e-01 -3.129260e-15 -2.168898 -8.023705e-01
# 4           -1.520892e+00 -3.129260e-15 -1.044343 -1.544907e+00

# %%
# 6. print the number of columns
print('No. of columns in X:', len(s_X_test.columns))
print('No. of rows in X:', len(s_X_test))
print('No. of nulls in X:', s_X_test.isna().sum().sum(), '\n')

print('No. of rows in Y:', len(s_y_test))
print('No. of nulls in Y:', s_y_test.isna().sum().sum())
# Out:
# No. of columns in X: 20
# No. of rows in X: 778
# No. of nulls in X: 0
#
# No. of rows in Y: 778
# No. of nulls in Y: 0

# %% [markdown]
# ###### **3.3. EVALUATE THE MODEL**

# %%
# 1. compute the Accuracy, Recall, Precision and F1-Score for test dataset.
s_y_test_pred = result.best_estimator_.predict(s_X_test)
print('============= Test Scores =============')
print('Accuracy Score:', accuracy_score(s_y_test, s_y_test_pred))
print('Recall Score:', recall_score(s_y_test, s_y_test_pred, average='micro'))
print('Precision Score:', precision_score(s_y_test, s_y_test_pred, average='micro'))
print('F1-Score:', f1_score(s_y_test, s_y_test_pred, average='micro'))
# Out:
# ============= Test Scores =============
# Accuracy Score: 0.7172236503856041
# Recall Score: 0.7172236503856041
# Precision Score: 0.7172236503856041
# F1-Score: 0.7172236503856041

# %%
# 2. plot confusion matrix
labels = np.array(sorted(MAP['ProgressoutcomeYOS2'].items(), key=lambda item: item[1]))[:,0]
plot_confusion_matrix(s_y_test, s_y_test_pred, labels)

# %%
# 3. Save the model.
with open('/content/gdrive/MyDrive/COMS HONS RESEARCH PROJECT/ensemble_trees_second_year.pkl', 'wb') as fid:
  pickle.dump(result.best_estimator_, fid)
